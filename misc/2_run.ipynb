# %% [markdown]
# # Run models

# %% [markdown]
# ### Import packages

# %%
from badlands.model import Model as badlandsModel

# %%
import numpy as np
np.arctan(np.radians(10))
# Out:
# 0.1727924348551592

# %% [markdown]
# ### Run models

# %%
time = 105000.

# # ### Shelf width ###

model = badlandsModel()
# Define the XmL input file
model.load_xml('xml/width/shelf_0.xml')
# Run model
model.run_to_time(time)

# initialise model
model = badlandsModel()
# Define the XmL input file
model.load_xml('xml/width/shelf_10.xml')
# Run model
model.run_to_time(time)

# initialise model
model = badlandsModel()
# Define the XmL input file
model.load_xml('xml/width/shelf_20.xml')
# Run model
model.run_to_time(time)

# initialise model
model = badlandsModel()
# Define the XmL input file
model.load_xml('xml/width/shelf_30.xml')
# Run model
model.run_to_time(time)

# initialise model
model = badlandsModel()
# Define the XmL input file
model.load_xml('xml/width/shelf_40.xml')
# Run model
model.run_to_time(time)

# initialise model
model = badlandsModel()
# Define the XmL input file
model.load_xml('xml/width/shelf_50.xml')
# Run model
model.run_to_time(time)

# # # ## Shelf angle ###

# initialise model
model = badlandsModel()
# Define the XmL input file
model.load_xml('xml/angle/shelfang_00.xml')
# Run model
model.run_to_time(time)

# initialise model
model = badlandsModel()
# Define the XmL input file
model.load_xml('xml/angle/shelfang_01.xml')
# Run model
model.run_to_time(time)

# initialise model
model = badlandsModel()
# Define the XmL input file
model.load_xml('xml/angle/shelfang_02.xml')
# Run model
model.run_to_time(time)

# initialise model
model = badlandsModel()
# Define the XmL input file
model.load_xml('xml/angle/shelfang_03.xml')
# Run model
model.run_to_time(time)

# initialise model
model = badlandsModel()
# Define the XmL input file
model.load_xml('xml/angle/shelfang_04.xml')
# Run model
model.run_to_time(time)

# initialise model
model = badlandsModel()
# Define the XmL input file
model.load_xml('xml/angle/shelfang_05.xml')
# Run model
model.run_to_time(time)

# ## Sea-level ###

# initialise model
model = badlandsModel()
# Define the XmL input file
model.load_xml('xml/sea/sea_0.xml')
# Run model
model.run_to_time(time)

# initialise model
model = badlandsModel()
# Define the XmL input file
model.load_xml('xml/sea/sea_15.xml')
# Run model
model.run_to_time(time)

# initialise model
model = badlandsModel()
# Define the XmL input file
model.load_xml('xml/sea/sea_30.xml')
# Run model
model.run_to_time(time)

# initialise model
model = badlandsModel()
# Define the XmL input file
model.load_xml('xml/sea/sea_60.xml')
# Run model
model.run_to_time(time)

# initialise model
model = badlandsModel()
# Define the XmL input file
model.load_xml('xml/sea/sea_120.xml')
# Run model
model.run_to_time(time)

# initialise model
model = badlandsModel()
# Define the XmL input file
model.load_xml('xml/sea/sea_240.xml')
# Run model
model.run_to_time(time)

# # # ## Shelf ero ###

# # initialise model
# model = badlandsModel()
# # Define the XmL input file
# model.load_xml('xml/shelf_ero/shelfero_3e6.xml')
# # Run model
# model.run_to_time(time)

# # initialise model
# model = badlandsModel()
# # Define the XmL input file
# model.load_xml('xml/shelf_ero/shelfero_4e6.xml')
# # Run model
# model.run_to_time(time)

# # initialise model
# model = badlandsModel()
# # Define the XmL input file
# model.load_xml('xml/shelf_ero/shelfero_5e6.xml')
# # Run model
# model.run_to_time(time)

# # initialise model
# model = badlandsModel()
# # Define the XmL input file
# model.load_xml('xml/shelf_ero/shelfero_6e6.xml')
# # Run model
# model.run_to_time(time)

# # initialise model
# model = badlandsModel()
# # Define the XmL input file
# model.load_xml('xml/shelf_ero/shelfero_7e6.xml')
# # Run model
# model.run_to_time(time)

# # initialise model
# model = badlandsModel()
# # Define the XmL input file
# model.load_xml('xml/shelf_ero/shelfero_8e6.xml')
# # Run model
# model.run_to_time(time)


# ### Critical density ###

# # initialise model
# model = badlandsModel()
# # Define the XmL input file
# model.load_xml('xml/dens/dens_05.xml')
# # Run model
# model.run_to_time(time)

# # initialise model
# model = badlandsModel()
# # Define the XmL input file
# model.load_xml('xml/dens/dens_06.xml')
# # Run model
# model.run_to_time(time)

# # initialise model
# model = badlandsModel()
# # Define the XmL input file
# model.load_xml('xml/dens/dens_07.xml')
# # Run model
# model.run_to_time(time)

# # initialise model
# model = badlandsModel()
# # Define the XmL input file
# model.load_xml('xml/dens/dens_08.xml')
# # Run model
# model.run_to_time(time)

# # initialise model
# model = badlandsModel()
# # Define the XmL input file
# model.load_xml('xml/dens/dens_09.xml')
# # Run model
# model.run_to_time(time)

# # initialise model
# model = badlandsModel()
# # Define the XmL input file
# model.load_xml('xml/dens/dens_10.xml')
# # Run model
# model.run_to_time(time)
# Out:
#    - Writing outputs (0.52 seconds; tNow = 0.0)
#    - Compute wave-induced sediment transport 3.35 seconds
#    - Writing outputs (0.40 seconds; tNow = 5000.0)
#    - Compute wave-induced sediment transport 3.13 seconds
#    - Writing outputs (0.42 seconds; tNow = 10000.0)
#    - Compute wave-induced sediment transport 3.11 seconds
#    - Writing outputs (0.40 seconds; tNow = 15000.0)
#    - Compute wave-induced sediment transport 0.63 seconds
#    - Writing outputs (0.47 seconds; tNow = 20000.0)
#    - Compute wave-induced sediment transport 3.05 seconds
#    - Writing outputs (0.40 seconds; tNow = 25000.0)
#    - Compute wave-induced sediment transport 2.96 seconds
#    - Writing outputs (0.41 seconds; tNow = 30000.0)
#    - Compute wave-induced sediment transport 2.93 seconds
#    - Writing outputs (0.39 seconds; tNow = 35000.0)
#    - Compute wave-induced sediment transport 2.80 seconds
#    - Writing outputs (0.39 seconds; tNow = 40000.0)
# ...
